// %% [markdown]
// # K-Means Example
//
// &emsp; Show capabilities processing iterative or recursive algorithms
// - Wayang API allows working with cycles
// - Enumerating process review if an operator was already processed
//
// &emsp; Review in detail how to work with Wayang API

// %% [markdown]
// ---
//
// ## Preparing dependancies

// %% [markdown]
// This step imports the required modules to execute the code. All these packages come from the previous Maven Instalation
//
// ```scala
// import $ivy.`ORGANIZATION:MODULE:VERSION` will bring the exact version
// import $ivy.`ORGANIZATION::MODULE:VERSION` the "::" bring the version of scala needed
// ```
//
// The imported libraries are:
//
// Module | Java's | Scala's | Description
// :----- | -------------: | --------------: | :----------
// wayang-core | 8, 11 | 2.11, 2.12 | provides core data structures and the optimizer (required)
// wayang-basic | 8, 11 | 2.11, 2.12 | provides common operators and data types for your apps (recommended)
// wayang-api-scala-java | 8, 11 | 2.11, 2.12 | provides an easy-to-use Scala and Java API to assemble wayang plans (recommended)
// wayang-spark | 8, 11 | 2.11, 2.12 | adapters for [Apache Spark](https://spark.apache.org) processing platforms
// hadoop-common | 8,11 | - | Hadoop-commons is required because the lack of the Environment Variable **HADOOP_HOME**

// %%
import $ivy.`com.thoughtworks.paranamer:paranamer:2.8`

import $ivy.`org.apache.wayang::wayang-api-scala-java:0.6.1-SNAPSHOT`
import $ivy.`org.apache.wayang:wayang-core:0.6.1-SNAPSHOT`
import $ivy.`org.apache.wayang:wayang-basic:0.6.1-SNAPSHOT`
import $ivy.`org.apache.wayang::wayang-spark:0.6.1-SNAPSHOT`
import $ivy.`org.apache.hadoop:hadoop-common:2.8.5`
// Out:
// Downloading https://repo1.maven.org/maven2/org/apache/hadoop/hadoop-common/2.8.5/hadoop-common-2.8.5.pom
// Downloaded https://repo1.maven.org/maven2/org/apache/hadoop/hadoop-common/2.8.5/hadoop-common-2.8.5.pom
// Downloading https://repo1.maven.org/maven2/org/apache/hadoop/hadoop-project-dist/2.8.5/hadoop-project-dist-2.8.5.pom
// Downloaded https://repo1.maven.org/maven2/org/apache/hadoop/hadoop-project-dist/2.8.5/hadoop-project-dist-2.8.5.pom
// Downloading https://repo1.maven.org/maven2/org/apache/hadoop/hadoop-project/2.8.5/hadoop-project-2.8.5.pom
// Downloaded https://repo1.maven.org/maven2/org/apache/hadoop/hadoop-project/2.8.5/hadoop-project-2.8.5.pom
// Downloading https://repo1.maven.org/maven2/org/apache/hadoop/hadoop-main/2.8.5/hadoop-main-2.8.5.pom
// Downloaded https://repo1.maven.org/maven2/org/apache/hadoop/hadoop-main/2.8.5/hadoop-main-2.8.5.pom
// Downloading https://repo1.maven.org/maven2/org/apache/zookeeper/zookeeper/3.4.6/zookeeper-3.4.6.pom
// Downloading https://repo1.maven.org/maven2/org/mortbay/jetty/jetty/6.1.26/jetty-6.1.26.pom
// Downloading https://repo1.maven.org/maven2/net/java/dev/jets3t/jets3t/0.9.0/jets3t-0.9.0.pom
// Downloading https://repo1.maven.org/maven2/com/jcraft/jsch/0.1.54/jsch-0.1.54.pom
// Downloading https://repo1.maven.org/maven2/commons-io/commons-io/2.4/commons-io-2.4.pom
// Downloading https://repo1.maven.org/maven2/commons-configuration/commons-configuration/1.6/commons-configuration-1.6.pom
// Downloaded https://repo1.maven.org/maven2/org/apache/zookeeper/zookeeper/3.4.6/zookeeper-3.4.6.pom
// Downloading https://repo1.maven.org/maven2/com/sun/jersey/jersey-json/1.9/jersey-json-1.9.pom
// Downloaded https://repo1.maven.org/maven2/com/sun/jersey/jersey-json/1.9/jersey-json-1.9.pom
// Downloading https://repo1.maven.org/maven2/commons-logging/commons-logging/1.1.3/commons-logging-1.1.3.pom
// Downloaded https://repo1.maven.org/maven2/net/java/dev/jets3t/jets3t/0.9.0/jets3t-0.9.0.pom
// Downloading https://repo1.maven.org/maven2/org/apache/commons/commons-compress/1
sources.jar
// Downloading https://repo1.maven.org/maven2/commons-io/commons-io/2.4/commons-io-2.4-sources.jar
// Downloading https://repo1.maven.org/maven2/com/sun/jersey/jersey-server/1.9/jersey-server-1.9.jar
// Downloading https://repo1.maven.org/maven2/javax/xml/stream/stax-api/1.0-2/stax-api-1.0-2.jar
// Downloading https://repo1.maven.org/maven2/org/tukaani/xz/1.0/xz-1.0.jar
// Downloaded https://repo1.maven.org/maven2/javax/xml/stream/stax-api/1.0-2/stax-api-1.0-2.jar
// Downloading https://repo1.maven.org/maven2/org/slf4j/slf4j-log4j12/1.7.10/slf4j-log4j12-1.7.10-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/apache/directory/api/api-asn1-api/1.0.0-M20/api-asn1-api-1.0.0-M20-sources.jar
// Downloading https://repo1.maven.org/maven2/org/apache/curator/curator-framework/2.7.1/curator-framework-2.7.1-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/tukaani/xz/1.0/xz-1.0.jar
// Downloading https://repo1.maven.org/maven2/com/jcraft/jsch/0.1.54/jsch-0.1.54-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/apache/htrace/htrace-core4/4.0.1-incubating/htrace-core4-4.0.1-incubating-sources.jar
// Downloading https://repo1.maven.org/maven2/commons-digester/commons-digester/1.8/commons-digester-1.8.jar
// Downloaded https://repo1.maven.org/maven2/org/slf4j/slf4j-log4j12/1.7.10/slf4j-log4j12-1.7.10-sources.jar
// Downloading https://repo1.maven.org/maven2/org/apache/directory/server/apacheds-i18n/2.0.0-M15/apacheds-i18n-2.0.0-M15.jar
// Downloaded https://repo1.maven.org/maven2/org/apache/directory/server/apacheds-i18n/2.0.0-M15/apacheds-i18n-2.0.0-M15.jar
// Downloading https://repo1.maven.org/maven2/commons-beanutils/commons-beanutils-core/1.8.0/commons-beanutils-core-1.8.0.jar
// Downloaded https://repo1.maven.org/maven2/com/jcraft/jsch/0.1.54/jsch-0.1.54-sources.jar
// Downloading https://repo1.maven.org/maven2/javax/activation/activation/1.1/activation-1.1-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/apache/curator/curator-framework/2.7.1/curator-framework-2.7.1-sources.jar
// Downloading https://repo1.maven.org/maven2/com/jamesmurty/utils/java-xmlbuilder/0.4/java-xmlbuilder-0.4.jar
// Downloaded https://repo1.maven.org/maven2/commons-digester/commons-digester/1.8/commons-digester-1.8.jar
// Downloading https://repo1.maven.org/maven2/com/sun/jersey/jersey-json/1.9/jersey-json-1.9.jar
// Downloaded https://repo1.maven.org/maven2/com/sun/jersey/jersey-server/1.9/jersey-server-1.9.jar
// Downloading https://repo1.maven.org/maven2/org/mortbay/jetty/jetty-util/6.1.26/jetty-util-6.1.26-sources.jar
// Downloaded https://repo1.maven.org/maven2/com/jamesmurty/utils/java-xmlbuilder/0.4/java-xmlbuilder-0.4.jar
// Downloading https://repo1.maven.org/maven2/commons-io/commons-io/2.4/commons-io-2.4.jar
// Downloaded https://repo1.maven.org/maven2/javax/activation/activation/1.1/activation-1.1-sources.jar
// Downloading https://repo1.maven.org/maven2/io/netty/netty/3.7.0.Final/netty-3.7.0.Final-sources.jar
// Downloaded https://repo1.maven.org/maven2/com/sun/jersey/jersey-json/1.9/jersey-json-1.9.jar
// Downloading https://repo1.maven.org/maven2/org/apache/curator/curator-client/2.7.1/curator-client-2.7.1-sources.jar
// Downloaded https://repo1.maven.org/maven2/commons-io/commons-io/2.4/commons-io-2.4-sources.jar
// Downloading https://repo1.maven.org/maven2/org/tukaani/xz/1.0/xz-1.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/mortbay/jetty/jetty-util/6.1.26/jetty-util-6.1.26-sources.jar
// Downloading https://repo1.maven.org/maven2/org/xerial/snappy/snappy-java/1.0.4.1/snappy-java-1.0.4.1.jar
// Downloaded https://repo1.maven.org/maven2/commons-beanutils/commons-beanutils-core/1.8.0/commons-beanutils-core-1.8.0.jar
// Downloading https://repo1.maven.org/maven2/net/java/dev/jets3t/jets3t/0.9.0/jets3t-0.9.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/apache/curator/curator-client/2.7.1/curator-client-2.7.1-sources.jar
// Downloading https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer/2.3/paranamer-2.3-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/tukaani/xz/1.0/xz-1.0-sources.jar
// Downloading https://repo1.maven.org/maven2/org/slf4j/slf4j-api/1.7.10/slf4j-api-1.7.10-sources.jar
// Downloaded https://repo1.maven.org/maven2/commons-io/commons-io/2.4/commons-io-2.4.jar
// Downloading https://repo1.maven.org/maven2/xmlenc/xmlenc/0.52/xmlenc-0.52.jar
// Downloaded https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer/2
sources.jar
// Downloaded https://repo1.maven.org/maven2/org/apache/directory/server/apacheds-kerberos-codec/2.0.0-M15/apacheds-kerberos-codec-2.0.0-M15-sources.jar
// Downloading https://repo1.maven.org/maven2/io/netty/netty/3.7.0.Final/netty-3.7.0.Final.jar
// Downloaded https://repo1.maven.org/maven2/org/apache/directory/api/api-asn1-api/1.0.0-M20/api-asn1-api-1.0.0-M20.jar
// Downloading https://repo1.maven.org/maven2/org/slf4j/slf4j-api/1.7.10/slf4j-api-1.7.10.jar
// Downloaded https://repo1.maven.org/maven2/com/sun/jersey/jersey-core/1.9/jersey-core-1.9-sources.jar
// Downloading https://repo1.maven.org/maven2/javax/activation/activation/1.1/activation-1.1.jar
// Downloaded https://repo1.maven.org/maven2/org/slf4j/slf4j-api/1.7.10/slf4j-api-1.7.10.jar
// Downloading https://repo1.maven.org/maven2/org/apache/avro/avro/1.7.4/avro-1.7.4.jar
// Downloaded https://repo1.maven.org/maven2/javax/activation/activation/1.1/activation-1.1.jar
// Downloading https://repo1.maven.org/maven2/commons-digester/commons-digester/1.8/commons-digester-1.8-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/apache/commons/commons-compress/1.4.1/commons-compress-1.4.1.jar
// Downloading https://repo1.maven.org/maven2/org/codehaus/jackson/jackson-jaxrs/1.8.3/jackson-jaxrs-1.8.3-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/apache/httpcomponents/httpclient/4.5.2/httpclient-4.5.2-sources.jar
// Downloading https://repo1.maven.org/maven2/commons-beanutils/commons-beanutils/1.7.0/commons-beanutils-1.7.0.jar
// Downloaded https://repo1.maven.org/maven2/org/codehaus/jackson/jackson-jaxrs/1.8.3/jackson-jaxrs-1.8.3-sources.jar
// Downloading https://repo1.maven.org/maven2/com/sun/jersey/jersey-core/1.9/jersey-core-1.9.jar
// Downloaded https://repo1.maven.org/maven2/org/apache/avro/avro/1.7.4/avro-1.7.4.jar
// Downloading https://repo1.maven.org/maven2/org/apache/avro/avro/1.7.4/avro-1.7.4-sources.jar
// Downloaded https://repo1.maven.org/maven2/commons-digester/commons-digester/1.8/commons-digester-1.8-sources.jar
// Downloading https://repo1.maven.org/maven2/org/apache/commons/commons-compress/1.4.1/commons-compress-1.4.1-sources.jar
// Downloaded https://repo1.maven.org/maven2/commons-beanutils/commons-beanutils/1.7.0/commons-beanutils-1.7.0.jar
// Downloading https://repo1.maven.org/maven2/org/apache/directory/api/api-util/1.0.0-M20/api-util-1.0.0-M20.jar
// Downloaded https://repo1.maven.org/maven2/io/netty/netty/3.7.0.Final/netty-3.7.0.Final.jar
// Downloading https://repo1.maven.org/maven2/org/apache/httpcomponents/httpcore/4.4.4/httpcore-4.4.4-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/apache/avro/avro/1.7.4/avro-1.7.4-sources.jar
// Downloading https://repo1.maven.org/maven2/org/apache/commons/commons-math3/3.1.1/commons-math3-3.1.1.jar
// Downloaded https://repo1.maven.org/maven2/com/sun/jersey/jersey-core/1.9/jersey-core-1.9.jar
// Downloading https://repo1.maven.org/maven2/org/mortbay/jetty/jetty/6.1.26/jetty-6.1.26-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/apache/directory/api/api-util/1.0.0-M20/api-util-1.0.0-M20.jar
// Downloading https://repo1.maven.org/maven2/javax/servlet/servlet-api/2.5/servlet-api-2.5.jar
// Downloaded https://repo1.maven.org/maven2/org/apache/commons/commons-compress/1.4.1/commons-compress-1.4.1-sources.jar
// Downloading https://repo1.maven.org/maven2/com/sun/jersey/jersey-server/1.9/jersey-server-1.9-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/apache/htrace/htrace-core4/4.0.1-incubating/htrace-core4-4.0.1-incubating.jar
// Downloading https://repo1.maven.org/maven2/commons-lang/commons-lang/2.6/commons-lang-2.6.jar
// Downloaded https://repo1.maven.org/maven2/commons-lang/commons-lang/2.6/commons-lang-2.6.jar
// Downloading https://repo1.maven.org/maven2/org/apache/curator/curator-recipes/2.7.1/curator-recipes-2.7.1.jar
// Downloaded https://repo1.maven.org/maven2/org/apache/curator/curator-recipes/2.7.1/curator-recipes-2.7.1.jar
// Downloading https://repo1.maven.org/maven2/commons-net/commons-net/3.1/commons-net-3.1.jar
// Downloaded https://repo1.maven.org/maven2/com/sun/jersey/jersey-server/1.9/jersey-server-1.9-sources.jar
// Downloading https://repo1.maven.org/maven2/commons-beanutils/commons-beanutils-core/1.8.0/commons-beanutils-core-1.8.0-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/commons-beanutils/commons-beanutils-core/1.8.0/commons-beanutils-core-1.8.0-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/apache/hadoop/hadoop-annotations/2.8.5/hadoop-annotations-2.8.5-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/commons-net/commons-net/3.1/commons-net-3.1.jar
// Downloading https://repo1.maven.org/maven2/xmlenc/xmlenc/0.52/xmlenc-0.52-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/xmlenc/xmlenc/0.52/xmlenc-0.52-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/apache/hadoop/hadoop-common/2.8.5/hadoop-common-2.8.5-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/apache/hadoop/hadoop-annotations/2.8.5/hadoop-annotations-2.8.5-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/apache/hadoop/hadoop-common/2.8.5/hadoop-common-2.8.5-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/apache/commons/commons-math3/3.1.1/commons-math3-3.1.1.jar
// Downloaded https://repo1.maven.org/maven2/org/apache/httpcomponents/httpcore/4.4.4/httpcore-4.4.4-sources.jar
// Downloaded https://repo1.maven.org/maven2/javax/servlet/servlet-api/2.5/servlet-api-2.5.jar
// Downloaded https://repo1.maven.org/maven2/org/mortbay/jetty/jetty/6.1.26/jetty-6.1.26-sources.jar
// import $ivy.$
//
//
// import $ivy.$
//
// import $ivy.$
//
// import $ivy.$
//
// import $ivy.$
//
// import $ivy.$

// %% [markdown]
// ---
//
// ## Import Class Section
//
// The classes that are required to run the code

// %%
import org.apache.wayang.api._
import org.apache.wayang.core.api.{Configuration, WayangContext}
import org.apache.wayang.core.util.fs.FileSystems
import org.apache.wayang.core.function.ExecutionContext
import org.apache.wayang.core.function.FunctionDescriptor.ExtendedSerializableFunction
import org.apache.wayang.core.plugin.Plugin
import org.apache.wayang.spark.Spark
import java.io.File
import java.util.{Collection => JavaCollection}
import scala.collection.JavaConversions._
import scala.util.Random
// Out:
// import org.apache.wayang.api._
//
// import org.apache.wayang.core.api.{Configuration, WayangContext}
//
// import org.apache.wayang.core.util.fs.FileSystems
//
// import org.apache.wayang.core.function.ExecutionContext
//
// import org.apache.wayang.core.function.FunctionDescriptor.ExtendedSerializableFunction
//
// import org.apache.wayang.core.plugin.Plugin
//
// import org.apache.wayang.spark.Spark
//
// import java.io.File
//
// import java.util.{Collection => JavaCollection}
//
// import scala.collection.JavaConversions._
//
// import scala.util.Random

// %%
/**
  * Represents objects with an x and a y coordinate.
  */
sealed trait PointLike {

  /**
    * @return the x coordinate
    */
  def x: Double

  /**
    * @return the y coordinate
    */
  def y: Double

}

/**
  * Represents a two-dimensional point.
  *
  * @param x the x coordinate
  * @param y the y coordinate
  */
case class Point(x: Double, y: Double) extends PointLike {

  /**
    * Calculates the Euclidean distance to another [[Point]].
    *
    * @param that the other [[PointLike]]
    * @return the Euclidean distance
    */
  def distanceTo(that: PointLike) = {
    val dx = this.x - that.x
    val dy = this.y - that.y
    math.sqrt(dx * dx + dy * dy)
  }

  override def toString: String = f"($x%.2f, $y%.2f)"
}

/**
  * Represents a two-dimensional point with a centroid ID attached.
  */
case class TaggedPoint(x: Double, y: Double, centroidId: Int) extends PointLike {

  /**
    * Creates a [[Point]] from this instance.
    *
    * @return the [[Point]]
    */
  def toPoint = Point(x, y)

}

/**
  * Represents a two-dimensional point with a centroid ID and a counter attached.
  */
case class TaggedPointCounter(x: Double, y: Double, centroidId: Int, count: Int = 1) extends PointLike {

  def this(point: PointLike, centroidId: Int, count: Int) = this(point.x, point.y, centroidId, count)

  /**
    * Adds coordinates and counts of two instances.
    *
    * @param that the other instance
    * @return the sum
    */
  def +(that: TaggedPointCounter) = TaggedPointCounter(this.x + that.x, this.y + that.y, this.centroidId, this.count + that.count)

  /**
    * Calculates the average of all added instances.
    *
    * @return a [[TaggedPoint]] reflecting the average
    */
  def average = TaggedPoint(x / count, y / count, centroidId)

}
// Out:
// Interrupted!
//   scala.reflect.internal.Types$AbstractArgsTypeRef.scala$reflect$internal$Types$NonClassTypeRef$$relativeInfoCacheValidForPeriod_$eq(Types.scala:2407)
//   scala.reflect.internal.Types$NonClassTypeRef.$init$(Types.scala:1920)
//   scala.reflect.internal.Types$AbstractArgsTypeRef.<init>(Types.scala:2407)
//   scala.reflect.internal.Types$TypeRef$.apply(Types.scala:2417)
//   scala.reflect.internal.Types.copyTypeRef(Types.scala:3648)
//   scala.reflect.internal.Types.copyTypeRef$(Types.scala:3640)
//   scala.reflect.internal.SymbolTable.copyTypeRef(SymbolTable.scala:28)
//   scala.reflect.internal.tpe.TypeMaps$TypeMap.mapOver(TypeMaps.scala:127)
//   scala.reflect.internal.tpe.TypeMaps$SubstMap.apply(TypeMaps.scala:793)
//   scala.reflect.internal.tpe.TypeMaps$TypeMap.mapOver(TypeMaps.scala:193)
//   scala.reflect.internal.tpe.TypeMaps$SubstMap.apply(TypeMaps.scala:793)
//   scala.reflect.internal.tpe.TypeMaps$SubstMap.apply(TypeMaps.scala:731)
//   scala.reflect.internal.tpe.TypeMaps$TypeMap.mapOver(TypeMaps.scala:123)
//   scala.reflect.internal.tpe.TypeMaps$SubstMap.apply(TypeMaps.scala:793)
//   scala.reflect.internal.Types$Type.subst(Types.scala:746)
//   scala.reflect.internal.Types$Type.instantiateTypeParams(Types.scala:493)
//   scala.reflect.internal.Types$TypeRef.seenFromOwnerInstantiated$1(Types.scala:2180)
//   scala.reflect.internal.Types$TypeRef.relativize(Types.scala:2184)
//   scala.reflect.internal.Types$TypeRef.$anonfun$baseTypeSeqImpl$2(Types.scala:2292)
//   scala.reflect.internal.Types$TypeRef$$Lambda$2166/0x0000000800b46840.apply(Unknown Source)
//   scala.reflect.internal.BaseTypeSeqs$BaseTypeSeq.map(BaseTypeSeqs.scala:157)
//   scala.reflect.internal.Types$TypeRef.baseTypeSeqImpl(Types.scala:2292)
//   scala.reflect.internal.Types.defineBaseTypeSeqOfTypeRef(Types.scala:2456)
//   scala.reflect.internal.Types.defineBaseTypeSeqOfTypeRef$(Types.scala:2447)
//   scala.reflect.internal.SymbolTable.defineBaseTypeSeqOfTypeRef(SymbolTable.scala:28)
//   scala.reflect.internal.Types$TypeRef.baseTypeSeq(Types.scala:2299)
//   scala.reflect.internal.BaseTypeSeqs.$anonfun$compoundBaseTypeSeq$1(BaseTypeSeqs.scala:205)
//   scala.reflect.internal.BaseTypeSeqs.compoundBaseTypeSeq(BaseTypeSeqs.scala:204)
//   scala.reflect.internal.BaseTypeSeqs.compoundBaseTypeSeq$(BaseTypeSeqs.scala:192)
//   scala.reflect.internal.SymbolTable.compoundBaseTypeSeq(SymbolTable.scala:28)
//   scala.reflect.internal.Types.defineBaseTypeSeqOfCompoundType(Types.scala:1528)
//   scala.reflect.internal.Types.defineBaseTypeSeqOfCompoundType$(Types.scala:1487)
//   scala.reflect.internal.SymbolTable.defineBaseTypeSeqOfCompoundType(SymbolTable.scala:28)
//   scala.reflect.internal.Types$CompoundType.baseTypeSeq(Types.scala:1395)
//   scala.reflect.internal.Types$PolyType.baseTypeSeq(Types.scala:2636)
//   scala.reflect.internal.Types$TypeRef.baseTypeSeqImpl(Types.scala:2286)
//   scala.reflect.internal.Types.defineBaseTypeSeqOfTypeRef(Types.scala:2456)
//   scala.reflect.internal.Types.defineBaseTypeSeqOfTypeRef$(Types.scala:2447)
//   scala.reflect.internal.SymbolTable.defineBaseTypeSeqOfTypeRef(SymbolTable.scala:28)
//   scala.reflect.internal.Types$TypeRef.baseTypeSeq(Types.scala:2299)
//   scala.reflect.internal.BaseTypeSeqs.$anonfun$compoundBaseTypeSeq$1(BaseTypeSeqs.scala:205)
//   scala.reflect.internal.BaseTypeSeqs.compoundBaseTypeSeq(BaseTypeSeqs.scala:204)
//   scala.reflect.internal.BaseTypeSeqs.compoundBaseTypeSeq$(BaseTypeSeqs.scala:192)
//   scala.reflect.internal.SymbolTable.compoundBaseTypeSeq(SymbolTable.scala:28)
//   scala.reflect.internal.Types.defineBaseTypeSeqOfCompoundType(Types.scala:1528)
//   scala.reflect.internal.Types.defineBaseTypeSeqOfCompoundType$(Types.scala:1487)
//   scala.reflect.internal.SymbolTable.defineBaseTypeSeqOfCompoundType(SymbolTable.scala:28)
//   scala.reflect.internal.Types$CompoundType.baseTypeSeq(Types.scala:1395)
//   scala.reflect.internal.Types$PolyType.baseTypeSeq(Types.scala:2636)
//   scala.reflect.internal.Types$TypeRef.baseTypeSeqImpl(Types.scala:2286)
//   scala.reflect.internal.Types.defineBaseTypeSeqOfTypeRef(Types.scala:2456)
//   scala.reflect.internal.Types.defineBaseTypeSeqOfTypeRef$(Types.scala:2447)
//   scala.reflect.internal.SymbolTable.defineBaseTypeSeqOfTypeRef(SymbolTable.scala:28)
//   scala.reflect.internal.Types$TypeRef.baseTypeSeq(Types.scala:2299)
//   scala.reflect.internal.BaseTypeSeqs.$anonfun$compoundBaseTypeSeq$1(BaseTypeSeqs.scala:205)
//   scala.reflect.internal.BaseTypeSeqs.compoundBaseTypeSeq(BaseTypeSeqs.scala:204)
//   scala.reflect.internal.BaseTypeSeqs.compoundBaseTypeSeq$(BaseTypeSeqs.scala:192)
//   scala.reflect.internal.SymbolTable.compoundBaseTypeSeq(SymbolTable.scala:28)
//   scala.reflect.internal.Types.defineBaseTypeSeqOfCompoundType(Types.scala:1528)
//   scala.reflect.internal.Types.defineBaseTypeSeqOfCompoundType$(Types.scala:1487)
//   scala.reflect.internal.SymbolTable.defineBaseTypeSeqOfCompoundType(SymbolTable.scala:28)
//   scala.reflect.internal.Types$CompoundType.baseTypeSeq(Types.scala:1395)
//   scala.reflect.internal.Types$PolyType.baseTypeSeq(Types.scala:2636)
//   scala.reflect.internal.Types$TypeRef.baseTypeSeqImpl(Types.scala:2286)
//   scala.reflect.internal.Types.defineBaseTypeSeqOfTypeRef(Types.scala:2456)
//   scala.reflect.internal.Types.defineBaseTypeSeqOfTypeRef$(Types.scala:2447)
//   scala.reflect.internal.SymbolTable.defineBaseTypeSeqOfTypeRef(SymbolTable.scala:28)
//   scala.reflect.internal.Types$TypeRef.baseTypeSeq(Types.scala:2299)
//   scala.reflect.internal.Types$Type.baseTypeIndex(Types.scala:922)
//   scala.reflect.internal.Types.isNew$1(Types.scala:1467)
//   scala.reflect.internal.Types.addMixinBaseClasses$1(Types.scala:1476)
//   scala.reflect.internal.Types.computeBaseClasses(Types.scala:1478)
//   scala.reflect.internal.Types.computeBaseClasses$(Types.scala:1455)
//   scala.reflect.internal.SymbolTable.computeBaseClasses(SymbolTable.scala:28)
//   scala.reflect.internal.Types.$anonfun$defineBaseClassesOfCompoundType$2(Types.scala:1556)
//   scala.reflect.internal.Types$$Lambda$533/0x00000008005f0040.apply(Unknown Source)
//   scala.reflect.internal.Types$CompoundType.memo(Types.scala:1426)
//   scala.reflect.internal.Types.defineBaseClassesOfCompoundType(Types.scala:1556)
//   scala.reflect.internal.Types.defineBaseClassesOfCompoundType$(Types.scala:1548)
//   scala.reflect.internal.SymbolTable.defineBaseClassesOfCompoundType(SymbolTable.scala:28)
//   scala.reflect.internal.Types$CompoundType.baseClasses(Types.scala:1409)
//   scala.reflect.internal.Types$PolyType.baseClasses(Types.scala:2638)
//   scala.reflect.internal.Types$TypeRef.baseClasses(Types.scala:2280)
//   scala.reflect.internal.Types.computeBaseClasses(Types.scala:1464)
//   scala.reflect.internal.Types.computeBaseClasses$(Types.scala:1455)
//   scala.reflect.internal.SymbolTable.computeBaseClasses(SymbolTable.scala:28)
//   scala.reflect.internal.Types.$anonfun$defineBaseClassesOfCompoundType$2(Types.scala:1556)
//   scala.reflect.internal.Types$$Lambda$533/0x00000008005f0040.apply(Unknown Source)
//   scala.reflect.internal.Types$CompoundType.memo(Types.scala:1426)
//   scala.reflect.internal.Types.defineBaseClassesOfCompoundType(Types.scala:1556)
//   scala.reflect.internal.Types.defineBaseClassesOfCompoundType$(Types.scala:1548)
//   scala.reflect.internal.SymbolTable.defineBaseClassesOfCompoundType(SymbolTable.scala:28)
//   scala.reflect.internal.Types$CompoundType.baseClasses(Types.scala:1409)
//   scala.reflect.internal.Types$PolyType.baseClasses(Types.scala:2638)
//   scala.reflect.internal.Symbols$Symbol.ancestors(Symbols.scala:2192)
//   scala.reflect.internal.Symbols$Symbol.mixinClasses(Symbols.scala:2188)
//   scala.tools.nsc.transform.ExplicitOuter.transformInfo(ExplicitOuter.scala:185)
//   scala.tools.nsc.transform.ExplicitOuter.transformInfo(ExplicitOuter.scala:201)
//   scala.tools.nsc.transform.InfoTransform$Phase$$anon$1.transform(InfoTransform.scala:45)
//   scala.reflect.internal.Symbols$Symbol.transformInfos(Symbols.scala:1659)
//   scala.reflect.internal.Symbols$Symbol.rawInfo(Symbols.scala:1642)
//   scala.reflect.internal.Symbols$Symbol.info(Symbols.scala:1521)
//   scala.reflect.internal.Symbols$Symbol.isDerivedValueClass(Symbols.scala:825)
//   scala.reflect.internal.transform.Erasure$ErasureMap.apply(Erasure.scala:143)
//   scala.reflect.internal.transform.Erasure$ErasureMap.apply(Erasure.scala:156)
//   scala.reflect.internal.transform.Erasure$ErasureMap.apply(Erasure.scala:147)
//   scala.reflect.internal.transform.Erasure.specialErasure(Erasure.scala:252)
//   scala.reflect.internal.transform.Erasure.specialErasure$(Erasure.scala:246)
//   scala.tools.nsc.transform.Erasure.specialErasure(Erasure.scala:22)
//   scala.reflect.internal.transform.Erasure.transformInfo(Erasure.scala:427)
//   scala.reflect.internal.transform.Erasure.transformInfo$(Erasure.scala:389)
//   scala.tools.nsc.transform.Erasure.transformInfo(Erasure.scala:22)
//   scala.tools.nsc.transform.InfoTransform$Phase$$anon$1.transform(InfoTransform.scala:45)
//   scala.reflect.internal.Symbols$Symbol.transformInfos(Symbols.scala:1659)
//   scala.reflect.internal.Symbols$Symbol.rawInfo(Symbols.scala:1642)
//   scala.tools.nsc.typechecker.Typers$Typer.isStale(Typers.scala:524)
//   scala.tools.nsc.typechecker.Typers$Typer.reallyExists(Typers.scala:516)
//   scala.tools.nsc.typechecker.Typers$Typer.typedSelect$1(Typers.scala:5037)
//   scala.tools.nsc.typechecker.Typers$Typer.typedSelectOrSuperCall$1(Typers.scala:5138)
//   scala.tools.nsc.typechecker.Typers$Typer.typed1(Typers.scala:5679)
//   scala.tools.nsc.transform.Erasure$Eraser.typed1(Erasure.scala:809)
//   scala.tools.nsc.typechecker.Typers$Typer.typed(Typers.scala:5724)
//   scala.tools.nsc.typechecker.Typers$Typer.$anonfun$typed1$39(Typers.scala:4832)
//   scala.tools.nsc.typechecker.Typers$Typer$$Lambda$2173/0x0000000800b51040.apply(Unknown Source)
//   scala.tools.nsc.typechecker.Typers$Typer.silent(Typers.scala:712)
//   scala.tools.nsc.typechecker.Typers$Typer.normalTypedApply$1(Typers.scala:4834)
//   scala.tools.nsc.typechecker.Typers$Typer.typedApply$1(Typers.scala:4862)
//   scala.tools.nsc.typechecker.Typers$Typer.typed1(Typers.scala:5678)
//   scala.tools.nsc.transform.Erasure$Eraser.typed1(Erasure.scala:809)
//   scala.tools.nsc.typechecker.Typers$Typer.typed(Typers.scala:5724)
//   scala.tools.nsc.typechecker.Typers$Typer.$anonfun$typedArg$1(Typers.scala:3353)
//   scala.tools.nsc.typechecker.Typers$Typer.typedArg(Typers.scala:490)
//   scala.tools.nsc.typechecker.PatternTypers$PatternTyper.typedArgWithFormal$1(PatternTypers.scala:113)
//   scala.tools.nsc.typechecker.PatternTypers$PatternTyper.$anonfun$typedArgsForFormals$4(PatternTypers.scala:127)
//   scala.tools.nsc.typechecker.PatternTypers$PatternTyper.typedArgsForFormals(PatternTypers.scala:127)
//   scala.tools.nsc.typechecker.PatternTypers$PatternTyper.typedArgsForFormals$(PatternTypers.scala:108)
//   scala.tools.nsc.typechecker.Typers$Typer.typedArgsForFormals(Typers.scala:201)
//   scala.tools.nsc.typechecker.Typers$Typer.handleMonomorphicCall$1(Typers.scala:3692)
//   scala.tools.nsc.typechecker.Typers$Typer.doTypedApply(Typers.scala:3725)
//   scala.tools.nsc.typechecker.Typers$Typer.normalTypedApply$1(Typers.scala:4853)
//   scala.tools.nsc.typechecker.Typers$Typer.typedApply$1(Typers.scala:4862)
//   scala.tools.nsc.typechecker.Typers$Typer.typed1(Typers.scala:5678)
//   scala.tools.nsc.transform.Erasure$Eraser.typed1(Erasure.scala:809)
//   scala.tools.nsc.typechecker.Typers$Typer.typed(Typers.scala:5724)
//   scala.tools.nsc.typechecker.Typers$Typer.typedBlock(Typers.scala:2496)
//   scala.tools.nsc.typechecker.Typers$Typer.$anonfun$typed1$103(Typers.scala:5653)
//   scala.tools.nsc.typechecker.Typers$Typer.typedOutsidePatternMode$1(Typers.scala:499)
//   scala.tools.nsc.typechecker.Typers$Typer.typed1(Typers.scala:5688)
//   scala.tools.nsc.transform.Erasure$Eraser.typed1(Erasure.scala:809)
//   scala.tools.nsc.typechecker.Typers$Typer.typed(Typers.scala:5724)
//   scala.tools.nsc.typechecker.Typers$Typer.typedTyped$1(Typers.scala:5451)
//   scala.tools.nsc.typechecker.Typers$Typer.typed1(Typers.scala:5681)
//   scala.tools.nsc.transform.Erasure$Eraser.typed1(Erasure.scala:809)
//   scala.tools.nsc.typechecker.Typers$Typer.typed(Typers.scala:5724)
//   scala.tools.nsc.typechecker.Typers$Typer.typedDefDef(Typers.scala:5940)
//   scala.tools.nsc.typechecker.Typers$Typer.typed1(Typers.scala:5643)
//   scala.tools.nsc.transform.Erasure$Eraser.typed1(Erasure.scala:809)
//   scala.tools.nsc.typechecker.Typers$Typer.typed(Typers.scala:5724)
//   scala.tools.nsc.typechecker.Typers$Typer.typedStat$1(Typers.scala:5788)
//   scala.tools.nsc.typechecker.Typers$Typer.$anonfun$typedStats$10(Typers.scala:3335)
//   scala.tools.nsc.typechecker.Typers$Typer.typedStats(Typers.scala:3335)
//   scala.tools.nsc.typechecker.Typers$Typer.typedTemplate(Typers.scala:2017)
//   scala.tools.nsc.typechecker.Typers$Typer.typedClassDef(Typers.scala:1830)
//   scala.tools.nsc.typechecker.Typers$Typer.typed1(Typers.scala:5644)
//   scala.tools.nsc.transform.Erasure$Eraser.typed1(Erasure.scala:809)
//   scala.tools.nsc.typechecker.Typers$Typer.typed(Typers.scala:5724)
//   scala.tools.nsc.typechecker.Typers$Typer.typedStat$1(Typers.scala:5788)
//   scala.tools.nsc.typechecker.Typers$Typer.$anonfun$typedStats$10(Typers.scala:3335)
//   scala.tools.nsc.typechecker.Typers$Typer.typedStats(Typers.scala:3335)
//   scala.tools.nsc.typechecker.Typers$Typer.typedTemplate(Typers.scala:2017)
//   scala.tools.nsc.typechecker.Typers$Typer.typedClassDef(Typers.scala:1830)
//   scala.tools.nsc.typechecker.Typers$Typer.typed1(Typers.scala:5644)
//   scala.tools.nsc.transform.Erasure$Eraser.typed1(Erasure.scala:809)
//   scala.tools.nsc.typechecker.Typers$Typer.typed(Typers.scala:5724)
//   scala.tools.nsc.typechecker.Typers$Typer.typedStat$1(Typers.scala:5788)
//   scala.tools.nsc.typechecker.Typers$Typer.$anonfun$typedStats$10(Typers.scala:3335)
//   scala.tools.nsc.typechecker.Typers$Typer.typedStats(Typers.scala:3335)
//   scala.tools.nsc.typechecker.Typers$Typer.typedTemplate(Typers.scala:2017)
//   scala.tools.nsc.typechecker.Typers$Typer.typedClassDef(Typers.scala:1830)
//   scala.tools.nsc.typechecker.Typers$Typer.typed1(Typers.scala:5644)
//   scala.tools.nsc.transform.Erasure$Eraser.typed1(Erasure.scala:809)
//   scala.tools.nsc.typechecker.Typers$Typer.typed(Typers.scala:5724)
//   scala.tools.nsc.typechecker.Typers$Typer.typedStat$1(Typers.scala:5788)
//   scala.tools.nsc.typechecker.Typers$Typer.$anonfun$typedStats$10(Typers.scala:3335)
//   scala.tools.nsc.typechecker.Typers$Typer.typedStats(Typers.scala:3335)
//   scala.tools.nsc.typechecker.Typers$Typer.typedPackageDef$1(Typers.scala:5354)
//   scala.tools.nsc.typechecker.Typers$Typer.typed1(Typers.scala:5647)
//   scala.tools.nsc.transform.Erasure$Eraser.typed1(Erasure.scala:809)
//   scala.tools.nsc.typechecker.Typers$Typer.typed(Typers.scala:5724)
//   scala.tools.nsc.typechecker.Typers$Typer.typedStat$1(Typers.scala:5788)
//   scala.tools.nsc.typechecker.Typers$Typer.$anonfun$typedStats$10(Typers.scala:3335)
//   scala.tools.nsc.typechecker.Typers$Typer.typedStats(Typers.scala:3335)
//   scala.tools.nsc.typechecker.Typers$Typer.typedPackageDef$1(Typers.scala:5354)
//   scala.tools.nsc.typechecker.Typers$Typer.typed1(Typers.scala:5647)
//   scala.tools.nsc.transform.Erasure$Eraser.typed1(Erasure.scala:809)
//   scala.tools.nsc.typechecker.Typers$Typer.typed(Typers.scala:5724)
//   scala.tools.nsc.transform.Erasure$ErasureTransformer.$anonfun$transform$2(Erasure.scala:1338)
//   scala.tools.nsc.transform.Erasure$ErasureTransformer.transform(Erasure.scala:1338)
//   scala.tools.nsc.transform.Erasure$ErasureTransformer.transform(Erasure.scala:863)
//   scala.tools.nsc.ast.Trees$Transformer.transformUnit(Trees.scala:147)
//   scala.tools.nsc.transform.Transform$Phase.apply(Transform.scala:37)
//   scala.tools.nsc.Global$GlobalPhase.applyPhase(Global.scala:454)
//   scala.tools.nsc.Global$GlobalPhase.run(Global.scala:402)
//   scala.tools.nsc.Global$Run.compileUnitsInternal(Global.scala:1511)
//   scala.tools.nsc.Global$Run.compileUnits(Global.scala:1495)
//   scala.tools.nsc.Global$Run.compileSources(Global.scala:1488)
//   scala.tools.nsc.Global$Run.compileFiles(Global.scala:1596)
//   ammonite.interp.Compiler$$anon$1.compile(Compiler.scala:344)
//   almond.Execute.withOutputHandler(Execute.scala:157)
//   almond.Execute.ammResult(Execute.scala:214)
//   almond.Execute.apply(Execute.scala:311)
//   almond.ScalaInterpreter.execute(ScalaInterpreter.scala:127)
//   almond.interpreter.InterpreterToIOInterpreter.$anonfun$execute$2(InterpreterToIOInterpreter.scala:69)
//   almond.interpreter.InterpreterToIOInterpreter$$Lambda$1073/0x00000008007fd840.apply(Unknown Source)
//   cats.effect.internals.IORunLoop$.cats$effect$internals$IORunLoop$$loop(IORunLoop.scala:87)
//   cats.effect.internals.IORunLoop$RestartCallback.signal(IORunLoop.scala:366)
//   cats.effect.internals.IORunLoop$RestartCallback.apply(IORunLoop.scala:387)
//   cats.effect.internals.IORunLoop$RestartCallback.apply(IORunLoop.scala:330)
//   cats.effect.internals.IOShift$Tick.run(IOShift.scala:36)
//   java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
//   java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
//   java.lang.Thread.run(Thread.java:829)

// %%
/**
  * UDF to select the closest centroid for a given [[Point]].
  */
class SelectNearestCentroid extends ExtendedSerializableFunction[Point, TaggedPointCounter] {

  /** Keeps the broadcasted centroids. */
  var centroids: JavaCollection[TaggedPoint] = _

  override def open(executionCtx: ExecutionContext) = {
    centroids = executionCtx.getBroadcast[TaggedPoint]("centroids")
  }

  override def apply(point: Point): TaggedPointCounter = {
    var minDistance = Double.PositiveInfinity
    var nearestCentroidId = -1
    for (centroid <- centroids) {
      val distance = point.distanceTo(centroid)
      if (distance < minDistance) {
        minDistance = distance
        nearestCentroidId = centroid.centroidId
      }
    }
    new TaggedPointCounter(point, nearestCentroidId, 1)
  }
}

// %%
/**
* Creates random centroids.
*
* @param n      the number of centroids to create
* @param random used to draw random coordinates
* @return the centroids
*/
def createRandomCentroids(n: Int, random: Random = new Random()) =
  // NOTE: The random cluster ID makes collisions during resurrection 
  //       less likely but in general permits ID collisions.
  for (i <- 1 to n) yield TaggedPoint(random.nextGaussian(), random.nextGaussian(), random.nextInt())

// %%
val inputFile = new File("files/census.txt").toURI().toString()
val k = 100
val iterations = 10

// %%
var plugin: Plugin = Spark.basicPlugin

// %%
class Kmeans(field0: Int, field1: Int) extends Serializable {
    
  def apply(plugin: Plugin, k: Int, inputFile: String, iterations: Int): Iterable[Point] = {
    val context = new WayangContext().withPlugin(plugin)
    val planBuilder = new PlanBuilder(context)
      
    // Read and parse the input file(s).
    val points = planBuilder
      .readTextFile(inputFile)
      .filter( line => line.trim.nonEmpty && !line.startsWith("caseid") )
      .map { line =>
        val fields = line.split(",")
        Point(fields(field0).toDouble, fields(field1).toDouble)
      }

    // Create initial centroids.
    val initialCentroids = planBuilder
      .loadCollection(createRandomCentroids(k))

    // Do the k-means loop.
    val finalCentroids = initialCentroids.repeat(iterations, { currentCentroids =>
      points
        .mapJava(
          new SelectNearestCentroid
        )
        .withBroadcast(currentCentroids, "centroids")
        .reduceByKey(_.centroidId, _ + _)
        .map(_.average)
    })

    // Collect the result.
    finalCentroids
      .map(_.toPoint)
      .collect()
  }
}

// %%
var result = new Kmeans(0, 1).apply(plugin, k, inputFile, iterations)
